# %%
import torch
import matplotlib.pyplot as plt

distilled_images_path = "/home/jennyni/MTT-contrastive-learning/distilled_data_cifar10_2023-08-2901:30:00.397113/distilled_images.pt"
labels_path = "/home/jennyni/MTT-contrastive-learning/label.pt"

# %%
distilled_images = torch.load(distilled_images_path)
labels = torch.load(labels_path)

num_classes = 10
ipc = 1

for i in range(num_classes):
    
    class_images = distilled_images[i * ipc: (i + 1) * ipc]
    class_labels = labels[i * ipc: (i + 1) * ipc]
        
    plt.figure(figsize=(3, 1))
    for j, img in enumerate(class_images):
        plt.subplot(1, ipc, j + 1)
        plt.imshow(img.detach().permute(1, 2, 0).numpy())
        plt.title(f"Class {class_labels[0].item()}")
        plt.axis('off')
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
# load distilled data
import torch
import matplotlib.pyplot as plt

distilled_images_path = "/home/jennyni/MTT-contrastive-learning/distilled_data_cifar10_2023-08-2901:30:00.397113/distilled_images.pt"
labels_path = "/home/jennyni/MTT-contrastive-learning/label.pt"

distilled_images = torch.load(distilled_images_path)
labels = torch.load(labels_path)

num_classes = 10
ipc = 10

for i in range(num_classes):
    
    class_images = distilled_images[i * ipc: (i + 1) * ipc]
    class_labels = labels[i * ipc: (i + 1) * ipc]
        
    plt.figure(figsize=(10, 5))
    for j, img in enumerate(class_images):
        plt.subplot(1, ipc, j + 1)
        
        plt.imshow(img.detach().permute(1, 2, 0).numpy())
        plt.title(f"Class {class_labels[0].item()}")
        plt.axis('off')
    plt.show()

# %%
distilled_images_path_before = "/home/jennyni/MTT-contrastive-learning/real_initial_images_2023-08-1800:50:15.614560.pt"
distilled_images_path_after = "/home/jennyni/MTT-contrastive-learning/distilled_data_cifar10_2023-08-1800:50:15.614560/distilled_images.pt"


distilled_images_before = torch.load(distilled_images_path_before)
distilled_images_path_after = torch.load(distilled_images_path_after)

print(distilled_images_before == distilled_images_path_after)
# Out:
# tensor([[[[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]],
#
#          [[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]],
#
#          [[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
# ...
